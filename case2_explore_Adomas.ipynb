# %%
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('HR_data.csv').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    HR_TD_Mean  HR_TD_Median  HR_TD_std  HR_TD_Min  HR_TD_Max  HR_TD_AUC  \
# 0   78.663878         76.70   7.480043      67.25      92.48  23048.450
# 1   76.540732         76.61   2.584756      69.82      82.33  23959.920
# 2   78.173563         77.92   2.681255      72.22      82.80  20324.605
# 3   83.073688         83.88   7.363598      69.42      96.12  24924.300
# 4   72.281250         72.91   3.193762      64.95      79.98  23052.100
#
#    HR_TD_Kurtosis  HR_TD_Skew  HR_TD_Slope_min  HR_TD_Slope_max  ...  upset  \
# 0       -1.091448    0.369955          -0.7300           0.9775  ...    1.0
# 1       -0.245338    0.338732          -0.3600           0.1900  ...    2.0
# 2       -0.615922   -0.233047          -0.6300           0.3575  ...    1.0
# 3       -0.866610   -0.046021          -0.4650           0.6500  ...    1.0
# 4        0.200401   -0.560948          -0.3725           0.3375  ...    3.0
#
#    hostile  alert  ashamed  inspired  nervous  attentive  afraid  active  \
# ...

# %%
pd.set_option('display.max_rows', None)
df.describe().T
# Out:
#                      count          mean          std           min  \
# HR_TD_Mean           312.0     78.549974    11.382695  5.760612e+01
# HR_TD_Median         312.0     77.452869    12.093798  5.413000e+01
# HR_TD_std            312.0      6.545680     4.998885  8.343897e-01
# HR_TD_Min            312.0     68.778365     9.341107  4.900000e+01
# HR_TD_Max            312.0     92.451122    17.759683  6.720000e+01
# HR_TD_AUC            312.0  24307.558590  4035.278119  1.485326e+04
# HR_TD_Kurtosis       312.0     -0.054661     1.671170 -1.644825e+00
# HR_TD_Skew           312.0      0.375978     0.823875 -2.230501e+00
# HR_TD_Slope_min      312.0     -0.567952     0.391239 -3.366000e+00
# HR_TD_Slope_max      312.0      0.518478     0.470043  7.500000e-02
# HR_TD_Slope_mean     312.0     -0.013455     0.051248 -2.304098e-01
# HR_TD_Slope          312.0     -0.013991     0.051847 -2.294408e-01
# TEMP_TD_Mean         312.0     32.905322     1.642753  2.932098e+01
# ...

# %%
pd.reset_option('display.max_rows')

# %%
# separate feature groups
emotion_cols = [ 'Frustrated', 'upset', 'hostile', 'alert',
       'ashamed', 'inspired', 'nervous', 'attentive', 'afraid', 'active',
       'determined']

feature_cols = [col for col in df.columns if '_' in col]

cat_cols = [col for col in df.columns if col not in emotion_cols+feature_cols]

# %%
df.Cohort.sort_values().unique()
# why the split of cohort d13?
# Out:
# array(['D1_1', 'D1_2', 'D1_3', 'D1_4', 'D1_5', 'D1_6'], dtype=object)

# %%
fig = px.scatter(
    data_frame=df[cat_cols].sort_values(by='Cohort'),
    x = 'Cohort',
    y = 'Individual',
    color='Cohort',
    template='simple_white',
    
)
fig.update_layout(
    width = 500,
    title = 'Are cohorts unique?'
)

fig.update_xaxes(showgrid=True, gridcolor='grey')
fig.update_yaxes(showgrid=True, gridcolor='grey',minor=dict(tickcolor="white", showgrid=True))
fig.show()

# %% [markdown]
# ## pca for Cohort and other labels

# %%
# Load the data
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import StandardScaler


data = pd.read_csv('HR_data.csv').drop(columns=['Unnamed: 0'])
data = data.dropna()

# Columns to exclude from PCA
cat_cols = [
     'Round', 'Phase', 'Cohort', 'Puzzler', 'Individual'
]
# Columns that are emotional states
emotion_cols = [
    'Frustrated', 'upset', 'hostile', 'alert', 'ashamed', 
    'inspired', 'nervous', 'attentive', 'afraid', 'active', 'determined'
]
feature_cols = [col for col in data.columns if col not in cat_cols+emotion_cols]

# prep the three datasets for PCA
feature_df = data[feature_cols].copy()
emo_df = data[emotion_cols].copy()
combo_df = data[feature_cols+emotion_cols].copy()

# Scaler Instance
scaler = StandardScaler()
#recombine cohort 3
data['cohort_recom'] = data.Cohort.str.split('_', expand=True)[1]
data['cohort_recom'] = data.cohort_recom.astype(int).apply(lambda x: 'd1_3' if x >= 3 else f'd1_{x}')

# choose labeling target
target = 'cohort_recom'


for df, label in zip([feature_df, emo_df, combo_df],['Feature PCA','Emotion PCA', 'PCA Score Plot']):
    df_scaled = scaler.fit_transform(df)

    # Apply PCA
    pca = PCA(n_components=2)  # Adjust based on your analysis
    principal_components = pca.fit_transform(df_scaled)

    

    # Create a DataFrame for plotting
    pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
    pca_df[target] = data[target]#.apply(lambda x: 'yes' if x == 1 else 'no')  
    # Plotting PCA results color-coded by emotion
    fig, ax = plt.subplots(figsize=(6, 4), dpi = 120)
    scatter = sns.scatterplot(x=pca_df['PC1'], y=pca_df['PC2'], hue=pca_df[target],s=20)
    plt.xlabel(f'Principal Component 1 ({round(pca.explained_variance_ratio_[0] * 100, 1)}%)')
    plt.ylabel(f'Principal Component 2 ({round(pca.explained_variance_ratio_[1] * 100, 1)}%)')
    plt.title(f'{label}')
    plt.legend(title = 'Cohort')
    #plt.colorbar(scatter)
    plt.grid(True)
    plt.show()

# %%
pca.components_
# Out:
# array([[-4.75318085e-03,  3.14825237e-04, -2.57308617e-02,
#          1.17074794e-02, -2.03676684e-02, -4.84189705e-03,
#         -1.21622669e-02, -2.69328205e-02,  1.92640194e-02,
#         -2.52153268e-02,  1.55989434e-02,  1.70232605e-02,
#          1.82904924e-01,  1.83026492e-01, -2.19513387e-02,
#          1.81610784e-01,  1.80720711e-01,  8.16654758e-02,
#         -3.84016661e-03, -1.77627100e-02,  1.37263051e-02,
#         -9.81911386e-03,  3.49483184e-02,  3.61165316e-02,
#          2.20599422e-01,  2.01710298e-01,  2.42950898e-01,
#         -1.02665121e-01,  2.46131728e-01,  2.21457685e-01,
#         -1.15368430e-01, -1.47876188e-01, -2.31976527e-01,
#          2.35909802e-01,  1.95583511e-01,  1.74107319e-01,
#          1.88934505e-01,  1.90015718e-01,  2.38564446e-01,
#          1.20672133e-01,  2.14118998e-01,  1.89720185e-01,
#          2.89705609e-02, -6.07272237e-02, -2.30130825e-01,
#          2.37166227e-01, -1.03964819e-02,  4.61241429e-03,
# ...

# %%
# Assuming 'features_scaled' has already been prepared and is ready for PCA
import numpy as np


pca = PCA()
components = pca.fit_transform(scaler.fit_transform(combo_df))

# Create a DataFrame with the loadings
loadings = pd.DataFrame(pca.components_.T, columns=[f'PC{i+1}' for i in range(len(pca.components_))], index=combo_df.columns)

# Plotting the explained variance
plt.figure(figsize=(8, 4))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.hlines(y = 0.95, xmax=60, xmin=0, linestyles='dashed')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot of Explained Variance')
plt.grid(True)
plt.show()

# Visualize the loadings for the first few components
plt.figure(figsize=(12, 16), dpi=120)
sns.heatmap(loadings.iloc[:, :2], cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Component Loadings')
plt.show()

# %%
loadings = loadings.reset_index()

# %%
np.sqrt(np.square(loadings.PC1[line]) + np.square(loadings.PC2[line]))
# Out:
# 0.19029169503657492

# %%
# make loading plot
# Loadings
jitter = ['left','right']*10
sign = [1,-1]*10

fig, ax = plt.subplots(dpi=120, figsize=(5,4))
sns.scatterplot(x = 'PC1',
                y = 'PC2',
                data = loadings,
                s = 50,
                legend = False)



#for line, jit, s in zip(range(0,loadings.shape[0]),jitter,sign):
     # if loadings.index[line] == 'Adhesiveness':
     #      jit = 'left'
     #      s = s*(-1)
for line in range(len(loadings)):
     cutoff = np.sqrt(np.square(loadings.PC1[line]) + np.square(loadings.PC2[line]))
     if cutoff >0.21:
          plt.text(loadings.PC1[line],#+0.01*s, 
                    loadings.PC2[line],#+0.03*s, 
                    loadings['index'][line], 
                    #horizontalalignment=jit, 
                    size=10, 
                    color='black')
                    
#plt.hlines(y = 0, xmin = -0.5, xmax = 0.5, color = 'black')

plt.xlabel('Principal Component 1')
plt.ylabel('Principal component 2')
plt.title(f'PCA Loading Plot')
plt.axhline(0, color = 'grey', linestyle = '--')
plt.axvline(0, color = 'grey', linestyle = '--')
plt.xlim(-0.3,0.3)
plt.ylim(-0.3,0.3)
#plt.title('Feature Loadings')
sns.despine()
#plt.grid()
plt.show()

# %% [markdown]
# At this point the argument is:
#
# - cohort d12 is separated from the other two cohorts.
# - separation mostly in PC1, by loadings from EDA-related features
# - EDA has been shown to be related to stress
#
# if cohort 3 generally higher in EDA-related signals, does that also reflect in the emotion questionaire:
# - are scores higher/lower for pre-puzzle phase in cohort d12

# %% [markdown]
# ## Test pre-puzzle phase emotion scores for cohorts

# %%
cat_cols
# Out:
# ['Round', 'Phase', 'Cohort', 'Puzzler', 'Individual']

# %%
# update cat_cols with recombined cohort d13
cat_cols = cat_cols + ['cohort_recom']

# %%
cohort_emotions_df = data[['Phase','cohort_recom']+emotion_cols].copy()
cohort_grouped = cohort_emotions_df.groupby(by=['cohort_recom','Phase'], as_index=False).mean()

# %%
for emo in emotion_cols:
    sns.barplot(
        data=cohort_emotions_df,
        x='Phase',
        y = emo,
        hue='cohort_recom'
    )
    plt.show()

# %% [markdown]
# ### Look into emotion score diff phase1 -> phase 2

# %%
emo_change_df = cohort_grouped.loc[cohort_grouped.Phase != 'phase3'].copy()
emo_change_df.sort_values(by=['cohort_recom','Phase',], ascending=False)
# Out:
#   cohort_recom   Phase  Frustrated     upset   hostile     alert   ashamed  \
# 7         d1_3  phase2    2.541667  1.458333  1.083333  2.875000  1.250000
# 6         d1_3  phase1    0.936170  1.063830  1.021277  2.212766  1.021277
# 4         d1_2  phase2    3.625000  1.958333  1.250000  3.041667  1.416667
# 3         d1_2  phase1    0.500000  1.041667  1.000000  1.583333  1.208333
# 1         d1_1  phase2    3.875000  1.750000  1.062500  2.187500  1.625000
# 0         d1_1  phase1    1.620690  1.137931  1.000000  2.000000  1.137931
#
#    inspired   nervous  attentive    afraid    active  determined
# 7  2.812500  1.562500   3.458333  1.041667  3.520833    3.604167
# 6  2.191489  1.425532   2.957447  1.106383  2.617021    3.063830
# 4  2.000000  1.541667   3.833333  1.166667  3.583333    3.625000
# 3  1.791667  1.416667   2.166667  1.000000  1.666667    2.458333
# 1  2.281250  1.218750   2.843750  1.000000  2.687500    2.906250
# ...

# %%
# Assuming your data is stored in a pandas DataFrame called 'emo_change_df'

# Step 1: Filter Data by Phase
phase1_data = emo_change_df[emo_change_df['Phase'] == 'phase1']
phase2_data = emo_change_df[emo_change_df['Phase'] == 'phase2']

# Step 2: Group by Cohort Recommendation
phase1_grouped = phase1_data.groupby('cohort_recom')
phase2_grouped = phase2_data.groupby('cohort_recom')

# Step 3: Calculate Mean Difference for Each Emotion
emotion_diff = {}
for emotion in emo_change_df.columns[2:]:  # Assuming the emotions start from the 4th column
    diff = {}
    for cohort, group1 in phase1_grouped:
        group2 = phase2_grouped.get_group(cohort)
        diff[cohort] = group2[emotion].mean() - group1[emotion].mean()
    emotion_diff[emotion] = diff

# Convert dictionary to DataFrame for easier manipulation
emotion_diff_df = pd.DataFrame(emotion_diff)

# Display the resulting DataFrame
emotion_diff_df
# Out:
#       Frustrated     upset   hostile     alert   ashamed  inspired   nervous  \
# d1_1    2.254310  0.612069  0.062500  0.187500  0.487069  0.246767 -0.367457
# d1_2    3.125000  0.916667  0.250000  1.458333  0.208333  0.208333  0.125000
# d1_3    1.605496  0.394504  0.062057  0.662234  0.228723  0.621011  0.136968
#
#       attentive    afraid    active  determined
# d1_1   0.464440  0.000000  0.790948    0.251078
# d1_2   1.666667  0.166667  1.916667    1.166667
# d1_3   0.500887 -0.064716  0.903812    0.540337

# %%
emotion_diff_df = emotion_diff_df.reset_index().melt(id_vars='index')

# %%
fig, ax = plt.subplots(figsize = (8,4), dpi = 120)
sns.barplot(
    data=emotion_diff_df,
    x='variable',
    y = 'value',
    hue = 'index'
)
sns.despine()
plt.title('Mean Emotion Score Change: Phase_1 -> Phase_2')
plt.ylabel('Difference')
plt.xlabel(' ')
plt.legend(title = 'Cohort')
plt.xticks(rotation = 60)
plt.show()
